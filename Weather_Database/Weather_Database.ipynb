# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from citipy import citipy
import time
from datetime import datetime
import gmaps
from config_1 import weather_api_key
from config_1 import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]

        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})
        
    except:
        print("City not found. Skipping...")
        
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | leua
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 1 | padang
# Processing Record 5 of Set 1 | nalut
# Processing Record 6 of Set 1 | ribeira grande
# Processing Record 7 of Set 1 | namibe
# Processing Record 8 of Set 1 | westport
# Processing Record 9 of Set 1 | lagoa
# Processing Record 10 of Set 1 | cody
# Processing Record 11 of Set 1 | raudeberg
# Processing Record 12 of Set 1 | one hundred mile house
# City not found. Skipping...
# Processing Record 13 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 1 | ko samui
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | ilam
# Processing Record 20 of Set 1 | flinders
# Processing Record 21 of Set 1 | tabou
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 1 | sitka
# Processing Record 25 of Set 1 | ust-omchug
# Processing Record 26 of Set 1 | saint-philippe
# Processing Record 27 of Set 1 | manuk mangkaw
# Processing Record 28 of Set 1 | hare bay
# Processing Record 29 of Set 1 | erzin
# Processing Record 30 of Set 1 | maldonado
# Processing Record 31 of Set 1 | port-gentil
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | chokurdakh
# Processing Record 34 of Set 1 | kilindoni
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | north myrtle beach
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | presidente epitacio
# Processing Record 40 of Set 1 | kaeo
# Processing Record 41 of Set 1 | oranjemund
# Processing Record 42 of Set 1 | takestan
# Processing Record 43 of Set 1 | seoul
# Processing Record 44 of Set 1 | vila velha
# Processing Record 45 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 1 | amuntai
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | kwekwe
# Processing Record 49 of Set 1 | tidore
# City not found. Skipping...
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | saint-pierre
# Processing Record 2 of Set 2 | mar del plata
# Processing Record 3 of Set 2 | katsuura
# Processing Record 4 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 2 | bambous virieux
# Processing Record 6 of Set 2 | lebu
# Processing Record 7 of Set 2 | torbay
# Processing Record 8 of Set 2 | lavrentiya
# Processing Record 9 of Set 2 | madimba
# Processing Record 10 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 2 | hattiesburg
# Processing Record 12 of Set 2 | port macquarie
# Processing Record 13 of Set 2 | pahrump
# Processing Record 14 of Set 2 | port elizabeth
# Processing Record 15 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 2 | isangel
# Processing Record 17 of Set 2 | camana
# Processing Record 18 of Set 2 | nouadhibou
# Processing Record 19 of Set 2 | ugoofaaru
# Processing Record 20 of Set 2 | fort nelson
# Processing Record 21 of Set 2 | aras
# Processing Record 22 of Set 2 | kissidougou
# Processing Record 23 of Set 2 | lubango
# Processing Record 24 of Set 2 | vestmannaeyjar
# Processing Record 25 of Set 2 | san patricio
# Processing Record 26 of Set 2 | lasa
# Processing Record 27 of Set 2 | cherskiy
# Processing Record 28 of Set 2 | kavieng
# Processing Record 29 of Set 2 | belle glade
# Processing Record 30 of Set 2 | humaita
# Processing Record 31 of Set 2 | port alfred
# Processing Record 32 of Set 2 | bontang
# Processing Record 33 of Set 2 | dikson
# Processing Record 34 of Set 2 | new norfolk
# Processing Record 35 of Set 2 | jamestown
# Processing Record 36 of Set 2 | jalu
# Processing Record 37 of Set 2 | yelan
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | labrea
# Processing Record 40 of Set 2 | namatanai
# Processing Record 41 of Set 2 | east london
# Processing Record 42 of Set 2 | savinka
# Processing Record 43 of Set 2 | pangnirtung
# Processing Record 44 of Set 2 | arman
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | big rapids
# Processing Record 47 of Set 2 | port-cartier
# Processing Record 48 of Set 2 | ilulissat
# Processing Record 49 of Set 2 | buala
# Processing Record 50 of Set 2 | kaitangata
# Processing Record 1 of Set 3 | lompoc
# Processing Record 2 of Set 3 | bethel
# Processing Record 3 of Set 3 | camacha
# Processing Record 4 of Set 3 | chuy
# Processing Record 5 of Set 3 | pevek
# Processing Record 6 of Set 3 | naze
# Processing Record 7 of Set 3 | alta floresta
# Processing Record 8 of Set 3 | dalvik
# Processing Record 9 of Set 3 | atuona
# Processing Record 10 of Set 3 | sampit
# Processing Record 11 of Set 3 | bluff
# Processing Record 12 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 3 | narsaq
# Processing Record 14 of Set 3 | verkhoyansk
# Processing Record 15 of Set 3 | alofi
# Processing Record 16 of Set 3 | port blair
# Processing Record 17 of Set 3 | xushan
# Processing Record 18 of Set 3 | ucluelet
# Processing Record 19 of Set 3 | ayan
# Processing Record 20 of Set 3 | derzhavinsk
# Processing Record 21 of Set 3 | lazarev
# Processing Record 22 of Set 3 | zhigansk
# Processing Record 23 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 3 | nikolskoye
# Processing Record 25 of Set 3 | kapit
# Processing Record 26 of Set 3 | mangaratiba
# Processing Record 27 of Set 3 | esna
# Processing Record 28 of Set 3 | gaya
# Processing Record 29 of Set 3 | nemuro
# Processing Record 30 of Set 3 | qaqortoq
# Processing Record 31 of Set 3 | usolye
# Processing Record 32 of Set 3 | castro
# Processing Record 33 of Set 3 | progreso
# Processing Record 34 of Set 3 | saskylakh
# Processing Record 35 of Set 3 | tawang
# Processing Record 36 of Set 3 | becerril
# Processing Record 37 of Set 3 | asau
# Processing Record 38 of Set 3 | buenos aires
# Processing Record 39 of Set 3 | todos santos
# Processing Record 40 of Set 3 | ust-tsilma
# Processing Record 41 of Set 3 | hirara
# Processing Record 42 of Set 3 | souillac
# Processing Record 43 of Set 3 | oktyabrskiy
# Processing Record 44 of Set 3 | esperance
# Processing Record 45 of Set 3 | oussouye
# Processing Record 46 of Set 3 | mitsamiouli
# Processing Record 47 of Set 3 | bukachacha
# Processing Record 48 of Set 3 | vila
# Processing Record 49 of Set 3 | yakima
# Processing Record 50 of Set 3 | hithadhoo
# Processing Record 1 of Set 4 | penzance
# Processing Record 2 of Set 4 | yellowknife
# Processing Record 3 of Set 4 | sur
# Processing Record 4 of Set 4 | mweka
# Processing Record 5 of Set 4 | aykhal
# Processing Record 6 of Set 4 | lewiston
# Processing Record 7 of Set 4 | hilo
# Processing Record 8 of Set 4 | chingirlau
# Processing Record 9 of Set 4 | ahipara
# Processing Record 10 of Set 4 | cockburn town
# Processing Record 11 of Set 4 | carnarvon
# Processing Record 12 of Set 4 | puerto escondido
# Processing Record 13 of Set 4 | general roca
# Processing Record 14 of Set 4 | bacolod
# Processing Record 15 of Set 4 | slave lake
# Processing Record 16 of Set 4 | ca mau
# Processing Record 17 of Set 4 | arucas
# Processing Record 18 of Set 4 | meulaboh
# Processing Record 19 of Set 4 | lufilufi
# Processing Record 20 of Set 4 | klaksvik
# Processing Record 21 of Set 4 | victoria
# Processing Record 22 of Set 4 | krasnoselkup
# Processing Record 23 of Set 4 | bonthe
# Processing Record 24 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 4 | yumen
# Processing Record 26 of Set 4 | nova olimpia
# Processing Record 27 of Set 4 | mishan
# Processing Record 28 of Set 4 | mahebourg
# Processing Record 29 of Set 4 | kirakira
# Processing Record 30 of Set 4 | tuktoyaktuk
# Processing Record 31 of Set 4 | damghan
# Processing Record 32 of Set 4 | isla vista
# Processing Record 33 of Set 4 | ostrovnoy
# Processing Record 34 of Set 4 | noumea
# Processing Record 35 of Set 4 | belaya gora
# Processing Record 36 of Set 4 | barberton
# Processing Record 37 of Set 4 | nichinan
# Processing Record 38 of Set 4 | saldanha
# Processing Record 39 of Set 4 | faanui
# Processing Record 40 of Set 4 | sao pedro do sul
# Processing Record 41 of Set 4 | yantzaza
# Processing Record 42 of Set 4 | olga
# Processing Record 43 of Set 4 | farafangana
# Processing Record 44 of Set 4 | port hardy
# Processing Record 45 of Set 4 | chulman
# Processing Record 46 of Set 4 | kodiak
# Processing Record 47 of Set 4 | lincoln
# Processing Record 48 of Set 4 | bathsheba
# Processing Record 49 of Set 4 | hinton
# Processing Record 50 of Set 4 | viedma
# Processing Record 1 of Set 5 | atambua
# Processing Record 2 of Set 5 | airai
# Processing Record 3 of Set 5 | balikpapan
# Processing Record 4 of Set 5 | qaanaaq
# Processing Record 5 of Set 5 | khatanga
# Processing Record 6 of Set 5 | sinnamary
# Processing Record 7 of Set 5 | burica
# City not found. Skipping...
# Processing Record 8 of Set 5 | hofn
# Processing Record 9 of Set 5 | severo-yeniseyskiy
# Processing Record 10 of Set 5 | lorengau
# Processing Record 11 of Set 5 | graham
# Processing Record 12 of Set 5 | severo-kurilsk
# Processing Record 13 of Set 5 | yeppoon
# Processing Record 14 of Set 5 | verkhnetulomskiy
# Processing Record 15 of Set 5 | arlit
# Processing Record 16 of Set 5 | grand gaube
# Processing Record 17 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 5 | tasiilaq
# Processing Record 19 of Set 5 | alabaster
# Processing Record 20 of Set 5 | bengkulu
# Processing Record 21 of Set 5 | fukue
# Processing Record 22 of Set 5 | nuevo casas grandes
# Processing Record 23 of Set 5 | sabang
# Processing Record 24 of Set 5 | guerrero negro
# Processing Record 25 of Set 5 | kazerun
# Processing Record 26 of Set 5 | sola
# Processing Record 27 of Set 5 | geraldton
# Processing Record 28 of Set 5 | longyearbyen
# Processing Record 29 of Set 5 | katangi
# Processing Record 30 of Set 5 | aberdeen
# Processing Record 31 of Set 5 | marabba
# Processing Record 32 of Set 5 | kasongo
# Processing Record 33 of Set 5 | kokkola
# Processing Record 34 of Set 5 | codrington
# Processing Record 35 of Set 5 | pangai
# Processing Record 36 of Set 5 | aswan
# Processing Record 37 of Set 5 | sai buri
# Processing Record 38 of Set 5 | busko-zdroj
# Processing Record 39 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 5 | qarchi gak
# Processing Record 41 of Set 5 | vizianagaram
# Processing Record 42 of Set 5 | santa isabel do rio negro
# Processing Record 43 of Set 5 | ixtapa
# Processing Record 44 of Set 5 | half moon bay
# Processing Record 45 of Set 5 | usak
# Processing Record 46 of Set 5 | axim
# Processing Record 47 of Set 5 | nome
# Processing Record 48 of Set 5 | nador
# Processing Record 49 of Set 5 | kutum
# Processing Record 50 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 6 | troitsko-pechorsk
# Processing Record 2 of Set 6 | nouakchott
# Processing Record 3 of Set 6 | shingu
# Processing Record 4 of Set 6 | tadine
# Processing Record 5 of Set 6 | marawi
# Processing Record 6 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 6 | havre-saint-pierre
# Processing Record 8 of Set 6 | huarmey
# Processing Record 9 of Set 6 | upernavik
# Processing Record 10 of Set 6 | saint anthony
# Processing Record 11 of Set 6 | ithaki
# Processing Record 12 of Set 6 | cabo san lucas
# Processing Record 13 of Set 6 | norman wells
# Processing Record 14 of Set 6 | harrismith
# Processing Record 15 of Set 6 | sindor
# Processing Record 16 of Set 6 | lulea
# Processing Record 17 of Set 6 | srednekolymsk
# Processing Record 18 of Set 6 | jaguey grande
# Processing Record 19 of Set 6 | georgetown
# Processing Record 20 of Set 6 | san lorenzo de el escorial
# Processing Record 21 of Set 6 | vanimo
# Processing Record 22 of Set 6 | komsomolskiy
# Processing Record 23 of Set 6 | mogadishu
# Processing Record 24 of Set 6 | merauke
# Processing Record 25 of Set 6 | constitucion
# Processing Record 26 of Set 6 | wencheng
# Processing Record 27 of Set 6 | kalasin
# Processing Record 28 of Set 6 | kesinga
# Processing Record 29 of Set 6 | teluk nibung
# Processing Record 30 of Set 6 | paamiut
# Processing Record 31 of Set 6 | baraki barak
# Processing Record 32 of Set 6 | gorontalo
# Processing Record 33 of Set 6 | siilinjarvi
# Processing Record 34 of Set 6 | chemax
# Processing Record 35 of Set 6 | finnsnes
# Processing Record 36 of Set 6 | dejen
# Processing Record 37 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 6 | taber
# Processing Record 39 of Set 6 | aguimes
# Processing Record 40 of Set 6 | kohlu
# Processing Record 41 of Set 6 | san quintin
# Processing Record 42 of Set 6 | murray bridge
# Processing Record 43 of Set 6 | saint george
# Processing Record 44 of Set 6 | berlevag
# Processing Record 45 of Set 6 | sabha
# Processing Record 46 of Set 6 | richards bay
# Processing Record 47 of Set 6 | casma
# Processing Record 48 of Set 6 | cayenne
# Processing Record 49 of Set 6 | umm kaddadah
# Processing Record 50 of Set 6 | luau
# Processing Record 1 of Set 7 | leningradskiy
# Processing Record 2 of Set 7 | gimbi
# Processing Record 3 of Set 7 | kimi
# City not found. Skipping...
# Processing Record 4 of Set 7 | pathein
# Processing Record 5 of Set 7 | mehamn
# Processing Record 6 of Set 7 | luderitz
# Processing Record 7 of Set 7 | mount gambier
# Processing Record 8 of Set 7 | aklavik
# Processing Record 9 of Set 7 | wittmund
# Processing Record 10 of Set 7 | road town
# Processing Record 11 of Set 7 | hobart
# Processing Record 12 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 7 | kloulklubed
# Processing Record 14 of Set 7 | myitkyina
# Processing Record 15 of Set 7 | salinopolis
# Processing Record 16 of Set 7 | pisco
# Processing Record 17 of Set 7 | reconquista
# Processing Record 18 of Set 7 | mokhsogollokh
# Processing Record 19 of Set 7 | santa maria
# Processing Record 20 of Set 7 | hambantota
# Processing Record 21 of Set 7 | portland
# Processing Record 22 of Set 7 | okhotsk
# Processing Record 23 of Set 7 | atasu
# Processing Record 24 of Set 7 | provideniya
# Processing Record 25 of Set 7 | abhar
# Processing Record 26 of Set 7 | sedelnikovo
# City not found. Skipping...
# Processing Record 27 of Set 7 | poya
# Processing Record 28 of Set 7 | port augusta
# Processing Record 29 of Set 7 | sisimiut
# Processing Record 30 of Set 7 | havelock
# Processing Record 31 of Set 7 | tres arroyos
# Processing Record 32 of Set 7 | lenine
# Processing Record 33 of Set 7 | huron
# Processing Record 34 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 35 of Set 7 | henties bay
# Processing Record 36 of Set 7 | ntcheu
# Processing Record 37 of Set 7 | trairi
# Processing Record 38 of Set 7 | mocuba
# Processing Record 39 of Set 7 | chara
# Processing Record 40 of Set 7 | bitung
# Processing Record 41 of Set 7 | kahului
# Processing Record 42 of Set 7 | adrar
# Processing Record 43 of Set 7 | kokopo
# Processing Record 44 of Set 7 | dunedin
# Processing Record 45 of Set 7 | melhus
# Processing Record 46 of Set 7 | inhambane
# Processing Record 47 of Set 7 | baykit
# Processing Record 48 of Set 7 | sao filipe
# Processing Record 49 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 7 | turukhansk
# Processing Record 1 of Set 8 | grottaglie
# Processing Record 2 of Set 8 | pochutla
# Processing Record 3 of Set 8 | yamada
# Processing Record 4 of Set 8 | nantucket
# Processing Record 5 of Set 8 | bad lippspringe
# Processing Record 6 of Set 8 | kruisfontein
# Processing Record 7 of Set 8 | puerto ayora
# Processing Record 8 of Set 8 | svetlyy
# Processing Record 9 of Set 8 | vagur
# Processing Record 10 of Set 8 | burnie
# Processing Record 11 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 12 of Set 8 | pimentel
# Processing Record 13 of Set 8 | bud
# Processing Record 14 of Set 8 | bardiyah
# Processing Record 15 of Set 8 | hobyo
# Processing Record 16 of Set 8 | kindu
# Processing Record 17 of Set 8 | cochrane
# Processing Record 18 of Set 8 | liku
# Processing Record 19 of Set 8 | gravelbourg
# Processing Record 20 of Set 8 | matara
# Processing Record 21 of Set 8 | winslow
# Processing Record 22 of Set 8 | magadan
# Processing Record 23 of Set 8 | pacific grove
# Processing Record 24 of Set 8 | chincha alta
# Processing Record 25 of Set 8 | karratha
# Processing Record 26 of Set 8 | gushikawa
# Processing Record 27 of Set 8 | houma
# Processing Record 28 of Set 8 | korla
# Processing Record 29 of Set 8 | victoria point
# Processing Record 30 of Set 8 | fortuna
# Processing Record 31 of Set 8 | kerman
# Processing Record 32 of Set 8 | batagay
# Processing Record 33 of Set 8 | oksfjord
# Processing Record 34 of Set 8 | singaraja
# Processing Record 35 of Set 8 | navabad
# City not found. Skipping...
# Processing Record 36 of Set 8 | giulianova
# Processing Record 37 of Set 8 | moron
# Processing Record 38 of Set 8 | gemena
# Processing Record 39 of Set 8 | vernon
# Processing Record 40 of Set 8 | amapa
# Processing Record 41 of Set 8 | vao
# Processing Record 42 of Set 8 | mormugao
# Processing Record 43 of Set 8 | grindavik
# Processing Record 44 of Set 8 | virginia beach
# Processing Record 45 of Set 8 | veraval
# Processing Record 46 of Set 8 | tevaitoa
# Processing Record 47 of Set 8 | port keats
# Processing Record 48 of Set 8 | la asuncion
# Processing Record 49 of Set 8 | wagar
# Processing Record 50 of Set 8 | yar-sale
# Processing Record 1 of Set 9 | iqaluit
# Processing Record 2 of Set 9 | dingle
# Processing Record 3 of Set 9 | antalaha
# Processing Record 4 of Set 9 | calvinia
# Processing Record 5 of Set 9 | payakumbuh
# Processing Record 6 of Set 9 | olafsvik
# Processing Record 7 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 8 of Set 9 | invermere
# Processing Record 9 of Set 9 | elliot lake
# Processing Record 10 of Set 9 | new ulm
# Processing Record 11 of Set 9 | eyl
# Processing Record 12 of Set 9 | bria
# Processing Record 13 of Set 9 | pokhara
# Processing Record 14 of Set 9 | caravelas
# Processing Record 15 of Set 9 | nanortalik
# Processing Record 16 of Set 9 | praya
# Processing Record 17 of Set 9 | dianopolis
# City not found. Skipping...
# Processing Record 18 of Set 9 | warrington
# Processing Record 19 of Set 9 | beaverlodge
# Processing Record 20 of Set 9 | bilma
# Processing Record 21 of Set 9 | lerwick
# Processing Record 22 of Set 9 | pitrufquen
# Processing Record 23 of Set 9 | almaznyy
# Processing Record 24 of Set 9 | roald
# Processing Record 25 of Set 9 | yulara
# Processing Record 26 of Set 9 | savannah bight
# Processing Record 27 of Set 9 | verkhnyaya inta
# Processing Record 28 of Set 9 | sao joao da barra
# Processing Record 29 of Set 9 | arraial do cabo
# Processing Record 30 of Set 9 | rincon
# Processing Record 31 of Set 9 | ponta do sol
# Processing Record 32 of Set 9 | manono
# Processing Record 33 of Set 9 | churapcha
# Processing Record 34 of Set 9 | touros
# Processing Record 35 of Set 9 | gasa
# Processing Record 36 of Set 9 | rio branco
# Processing Record 37 of Set 9 | namtsy
# Processing Record 38 of Set 9 | pasni
# Processing Record 39 of Set 9 | rimbey
# Processing Record 40 of Set 9 | octeville
# Processing Record 41 of Set 9 | clyde river
# Processing Record 42 of Set 9 | nylstroom
# City not found. Skipping...
# Processing Record 43 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 44 of Set 9 | basco
# Processing Record 45 of Set 9 | mpongwe
# Processing Record 46 of Set 9 | praia da vitoria
# Processing Record 47 of Set 9 | logan
# Processing Record 48 of Set 9 | utete
# Processing Record 49 of Set 9 | sawtell
# Processing Record 50 of Set 9 | baherden
# Processing Record 1 of Set 10 | bandarbeyla
# Processing Record 2 of Set 10 | am timan
# Processing Record 3 of Set 10 | mabaruma
# Processing Record 4 of Set 10 | faya
# Processing Record 5 of Set 10 | meadow lake
# Processing Record 6 of Set 10 | sinjar
# Processing Record 7 of Set 10 | qibili
# City not found. Skipping...
# Processing Record 8 of Set 10 | kimbe
# Processing Record 9 of Set 10 | fairbanks
# Processing Record 10 of Set 10 | kudahuvadhoo
# Processing Record 11 of Set 10 | port lincoln
# Processing Record 12 of Set 10 | rocha
# Processing Record 13 of Set 10 | kabalo
# Processing Record 14 of Set 10 | san policarpo
# Processing Record 15 of Set 10 | catazaja
# Processing Record 16 of Set 10 | ceres
# Processing Record 17 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 18 of Set 10 | wakkanai
# Processing Record 19 of Set 10 | morondava
# Processing Record 20 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 10 | walvis bay
# Processing Record 22 of Set 10 | gat
# Processing Record 23 of Set 10 | altamira
# Processing Record 24 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 10 | bowen
# Processing Record 26 of Set 10 | olinda
# Processing Record 27 of Set 10 | tateyama
# Processing Record 28 of Set 10 | yashkul
# Processing Record 29 of Set 10 | roma
# Processing Record 30 of Set 10 | sangat
# Processing Record 31 of Set 10 | aksarka
# Processing Record 32 of Set 10 | nizhnyaya poyma
# Processing Record 33 of Set 10 | tiksi
# Processing Record 34 of Set 10 | ishigaki
# Processing Record 35 of Set 10 | the valley
# Processing Record 36 of Set 10 | porto san giorgio
# Processing Record 37 of Set 10 | oranjestad
# Processing Record 38 of Set 10 | menongue
# Processing Record 39 of Set 10 | luquillo
# Processing Record 40 of Set 10 | nishihara
# Processing Record 41 of Set 10 | opuwo
# Processing Record 42 of Set 10 | lata
# Processing Record 43 of Set 10 | hoquiam
# Processing Record 44 of Set 10 | abu kamal
# Processing Record 45 of Set 10 | agbor
# Processing Record 46 of Set 10 | hastings
# Processing Record 47 of Set 10 | kedgwick
# Processing Record 48 of Set 10 | kuryk
# Processing Record 49 of Set 10 | kabompo
# Processing Record 50 of Set 10 | klyuchi
# Processing Record 1 of Set 11 | yuzhou
# Processing Record 2 of Set 11 | buraydah
# Processing Record 3 of Set 11 | bilibino
# Processing Record 4 of Set 11 | bereda
# Processing Record 5 of Set 11 | martapura
# Processing Record 6 of Set 11 | san gavino monreale
# Processing Record 7 of Set 11 | ngunguru
# Processing Record 8 of Set 11 | huilong
# Processing Record 9 of Set 11 | ulundurpettai
# City not found. Skipping...
# Processing Record 10 of Set 11 | kharan
# Processing Record 11 of Set 11 | las palmas
# Processing Record 12 of Set 11 | monrovia
# Processing Record 13 of Set 11 | husavik
# Processing Record 14 of Set 11 | soconusco
# Processing Record 15 of Set 11 | ossora
# Processing Record 16 of Set 11 | broome
# Processing Record 17 of Set 11 | bama
# Processing Record 18 of Set 11 | kalmar
# Processing Record 19 of Set 11 | areosa
# Processing Record 20 of Set 11 | poum
# Processing Record 21 of Set 11 | ketchikan
# Processing Record 22 of Set 11 | muisne
# Processing Record 23 of Set 11 | bethanien
# Processing Record 24 of Set 11 | kashi
# Processing Record 25 of Set 11 | dunmore town
# Processing Record 26 of Set 11 | thompson
# Processing Record 27 of Set 11 | umarkot
# Processing Record 28 of Set 11 | ancud
# Processing Record 29 of Set 11 | sistranda
# Processing Record 30 of Set 11 | verkhnevilyuysk
# Processing Record 31 of Set 11 | bongaree
# Processing Record 32 of Set 11 | hami
# Processing Record 33 of Set 11 | front royal
# Processing Record 34 of Set 11 | dezhou
# Processing Record 35 of Set 11 | hay river
# Processing Record 36 of Set 11 | kasongo-lunda
# Processing Record 37 of Set 11 | portree
# Processing Record 38 of Set 11 | sioux lookout
# Processing Record 39 of Set 11 | severomuysk
# Processing Record 40 of Set 11 | kingsport
# Processing Record 41 of Set 11 | kasane
# Processing Record 42 of Set 11 | santa luzia
# Processing Record 43 of Set 11 | cidreira
# Processing Record 44 of Set 11 | chapais
# Processing Record 45 of Set 11 | ternate
# Processing Record 46 of Set 11 | fuxin
# Processing Record 47 of Set 11 | tobane
# Processing Record 48 of Set 11 | dudinka
# Processing Record 49 of Set 11 | harrislee
# Processing Record 50 of Set 11 | hovd
# Processing Record 1 of Set 12 | ivrea
# Processing Record 2 of Set 12 | huambo
# Processing Record 3 of Set 12 | paita
# Processing Record 4 of Set 12 | lumeje
# Processing Record 5 of Set 12 | aasiaat
# Processing Record 6 of Set 12 | morehead
# Processing Record 7 of Set 12 | mayya
# Processing Record 8 of Set 12 | tura
# Processing Record 9 of Set 12 | yantal
# Processing Record 10 of Set 12 | batemans bay
# Processing Record 11 of Set 12 | muros
# Processing Record 12 of Set 12 | pacifica
# Processing Record 13 of Set 12 | rio grande
# Processing Record 14 of Set 12 | betafo
# Processing Record 15 of Set 12 | ilorin
# Processing Record 16 of Set 12 | brae
# Processing Record 17 of Set 12 | ewo
# Processing Record 18 of Set 12 | acarau
# Processing Record 19 of Set 12 | songjianghe
# Processing Record 20 of Set 12 | linares
# Processing Record 21 of Set 12 | jolalpan
# Processing Record 22 of Set 12 | mackay
# Processing Record 23 of Set 12 | yilan
# Processing Record 24 of Set 12 | north bend
# Processing Record 25 of Set 12 | sao raimundo nonato
# Processing Record 26 of Set 12 | halifax
# Processing Record 27 of Set 12 | coolum beach
# Processing Record 28 of Set 12 | shache
# Processing Record 29 of Set 12 | terra roxa
# Processing Record 30 of Set 12 | concarneau
# Processing Record 31 of Set 12 | carutapera
# Processing Record 32 of Set 12 | agadir
# Processing Record 33 of Set 12 | gretna
# Processing Record 34 of Set 12 | margate
# Processing Record 35 of Set 12 | prainha
# Processing Record 36 of Set 12 | nortelandia
# Processing Record 37 of Set 12 | parana
# Processing Record 38 of Set 12 | dhidhdhoo
# Processing Record 39 of Set 12 | hamilton
# Processing Record 40 of Set 12 | novobataysk
# Processing Record 41 of Set 12 | portoferraio
# Processing Record 42 of Set 12 | goundam
# Processing Record 43 of Set 12 | dibaya
# City not found. Skipping...
# Processing Record 44 of Set 12 | barcelos
# Processing Record 45 of Set 12 | montes claros
# Processing Record 46 of Set 12 | adre
# Processing Record 47 of Set 12 | george
# Processing Record 48 of Set 12 | mackenzie
# Processing Record 49 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 50 of Set 12 | pousat
# City not found. Skipping...
# Processing Record 1 of Set 13 | sorland
# Processing Record 2 of Set 13 | mugur-aksy
# Processing Record 3 of Set 13 | ayios kirikos
# City not found. Skipping...
# Processing Record 4 of Set 13 | pastavy
# Processing Record 5 of Set 13 | jacareacanga
# Processing Record 6 of Set 13 | mapiripan
# Processing Record 7 of Set 13 | caibarien
# Processing Record 8 of Set 13 | tosu
# Processing Record 9 of Set 13 | sydney
# Processing Record 10 of Set 13 | kununurra
# Processing Record 11 of Set 13 | capaci
# Processing Record 12 of Set 13 | mingguang
# Processing Record 13 of Set 13 | riberalta
# Processing Record 14 of Set 13 | kattivakkam
# Processing Record 15 of Set 13 | unhel
# Processing Record 16 of Set 13 | wenling
# Processing Record 17 of Set 13 | waingapu
# Processing Record 18 of Set 13 | chapada dos guimaraes
# Processing Record 19 of Set 13 | gazion
# City not found. Skipping...
# Processing Record 20 of Set 13 | christchurch
# Processing Record 21 of Set 13 | nesbyen
# Processing Record 22 of Set 13 | reserva
# Processing Record 23 of Set 13 | fonte boa
# Processing Record 24 of Set 13 | aksu
# Processing Record 25 of Set 13 | aleksandrov gay
# Processing Record 26 of Set 13 | impfondo
# Processing Record 27 of Set 13 | cherdyn
# Processing Record 28 of Set 13 | akdepe
# Processing Record 29 of Set 13 | booue
# Processing Record 30 of Set 13 | comodoro rivadavia
# Processing Record 31 of Set 13 | dauphin
# Processing Record 32 of Set 13 | kutulik
# Processing Record 33 of Set 13 | caranavi
# Processing Record 34 of Set 13 | santa vitoria do palmar
# Processing Record 35 of Set 13 | havoysund
# Processing Record 36 of Set 13 | teya
# Processing Record 37 of Set 13 | makushino
# Processing Record 38 of Set 13 | do gonbadan
# Processing Record 39 of Set 13 | ulagan
# Processing Record 40 of Set 13 | kipini
# Processing Record 41 of Set 13 | cerrito
# Processing Record 42 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 43 of Set 13 | santa cruz
# Processing Record 44 of Set 13 | topeka
# Processing Record 45 of Set 13 | imbituba
# Processing Record 46 of Set 13 | hokitika
# Processing Record 47 of Set 13 | yerbogachen
# Processing Record 48 of Set 13 | kieta
# Processing Record 49 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 50 of Set 13 | schwabisch gmund
# Processing Record 1 of Set 14 | felipe carrillo puerto
# Processing Record 2 of Set 14 | chioggia
# Processing Record 3 of Set 14 | puerto madryn
# Processing Record 4 of Set 14 | tanjong tokong
# City not found. Skipping...
# Processing Record 5 of Set 14 | mut
# Processing Record 6 of Set 14 | tazovskiy
# Processing Record 7 of Set 14 | zverinogolovskoye
# Processing Record 8 of Set 14 | caruray
# Processing Record 9 of Set 14 | la merced
# Processing Record 10 of Set 14 | miyazu
# Processing Record 11 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 12 of Set 14 | basar
# Processing Record 13 of Set 14 | uarini
# Processing Record 14 of Set 14 | gornopravdinsk
# Processing Record 15 of Set 14 | severnoye
# Processing Record 16 of Set 14 | maniitsoq
# Processing Record 17 of Set 14 | hasaki
# Processing Record 18 of Set 14 | gizo
# Processing Record 19 of Set 14 | northam
# Processing Record 20 of Set 14 | biak
# Processing Record 21 of Set 14 | novyy urengoy
# Processing Record 22 of Set 14 | popondetta
# Processing Record 23 of Set 14 | kelowna
# Processing Record 24 of Set 14 | charlestown
# Processing Record 25 of Set 14 | skibbereen
# Processing Record 26 of Set 14 | sumbawanga
# Processing Record 27 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 14 | elk plain
# Processing Record 29 of Set 14 | tungkang
# City not found. Skipping...
# Processing Record 30 of Set 14 | coos bay
# Processing Record 31 of Set 14 | miranorte
# City not found. Skipping...
# Processing Record 32 of Set 14 | maxixe
# Processing Record 33 of Set 14 | rawson
# Processing Record 34 of Set 14 | yaroslavl
# Processing Record 35 of Set 14 | saint-augustin
# Processing Record 36 of Set 14 | jacmel
# Processing Record 37 of Set 14 | kaniama
# Processing Record 38 of Set 14 | homer
# Processing Record 39 of Set 14 | pravia
# Processing Record 40 of Set 14 | mount isa
# Processing Record 41 of Set 14 | jiangyin
# Processing Record 42 of Set 14 | coquimbo
# Processing Record 43 of Set 14 | muromtsevo
# Processing Record 44 of Set 14 | santa rosa
# Processing Record 45 of Set 14 | cienfuegos
# Processing Record 46 of Set 14 | muroto
# Processing Record 47 of Set 14 | laguna
# Processing Record 48 of Set 14 | chepareria
# Processing Record 49 of Set 14 | shakawe
# Processing Record 50 of Set 14 | asyut
# Processing Record 1 of Set 15 | podgorica
# Processing Record 2 of Set 15 | urambo
# Processing Record 3 of Set 15 | coahuayana
# Processing Record 4 of Set 15 | varnavino
# Processing Record 5 of Set 15 | hit
# Processing Record 6 of Set 15 | thunder bay
# Processing Record 7 of Set 15 | novikovo
# Processing Record 8 of Set 15 | santa elena
# Processing Record 9 of Set 15 | nauta
# Processing Record 10 of Set 15 | rochegda
# Processing Record 11 of Set 15 | te anau
# Processing Record 12 of Set 15 | makinsk
# Processing Record 13 of Set 15 | berdigestyakh
# Processing Record 14 of Set 15 | nhulunbuy
# Processing Record 15 of Set 15 | lusambo
# Processing Record 16 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 15 | surgut
# Processing Record 18 of Set 15 | daru
# Processing Record 19 of Set 15 | nyurba
# Processing Record 20 of Set 15 | payo
# Processing Record 21 of Set 15 | pulaski
# Processing Record 22 of Set 15 | zapolyarnyy
# Processing Record 23 of Set 15 | salalah
# Processing Record 24 of Set 15 | kysyl-syr
# Processing Record 25 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 26 of Set 15 | parabel
# Processing Record 27 of Set 15 | tiznit
# Processing Record 28 of Set 15 | tahe
# Processing Record 29 of Set 15 | tilichiki
# Processing Record 30 of Set 15 | sao miguel do araguaia
# Processing Record 31 of Set 15 | bolonchen
# City not found. Skipping...
# Processing Record 32 of Set 15 | ondangwa
# Processing Record 33 of Set 15 | kalmunai
# Processing Record 34 of Set 15 | alice springs
# Processing Record 35 of Set 15 | puerto morazan
# Processing Record 36 of Set 15 | karasjok
# Processing Record 37 of Set 15 | santiago de cao
# Processing Record 38 of Set 15 | filingue
# Processing Record 39 of Set 15 | bulgan
# Processing Record 40 of Set 15 | eureka
# Processing Record 41 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 15 | shiyan
# Processing Record 43 of Set 15 | yining
# Processing Record 44 of Set 15 | saint-francois
# Processing Record 45 of Set 15 | sukhobezvodnoye
# Processing Record 46 of Set 15 | socorro
# Processing Record 47 of Set 15 | nara
# Processing Record 48 of Set 15 | bida
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Leua      SK  48.2156   18.6071     68.99        64          99
# 1          Barrow      US  71.2906 -156.7887     35.62        93         100
# 2          Padang      ID  -0.9492  100.3543     84.25        73          99
# 3           Nalut      LY  30.3333   10.8500     78.31        24           0
# 4  Ribeira Grande      PT  38.5167  -28.7000     74.39        87          13
# 5          Namibe      AO -15.1961   12.1522     63.30        72           8
# 6        Westport      US  41.1415  -73.3579     76.48        89         100
# 7           Lagoa      PT  39.0500  -27.9833     73.29        89           2
# 8            Cody      US  44.5263 -109.0565     71.82        41          40
# 9       Raudeberg      NO  61.9875    5.1352     54.95        96         100
#
#    Wind Speed Current Description
# 0        4.88     overcast clouds
# 1       32.21     overcast clouds
# 2        3.24     overcast clouds
# 3        7.23           clear sky
# 4        6.71          few clouds
# 5        6.73           clear sky
# 6        6.91     overcast clouds
# 7       10.89          light rain
# 8        6.91    scattered clouds
# 9       22.35          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
